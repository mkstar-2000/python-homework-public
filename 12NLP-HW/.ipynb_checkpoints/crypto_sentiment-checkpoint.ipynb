# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
#     - *bitcoin*
# 2. Which coin had the highest negative score?
#     - *bitcoin*
# 3. Which coin had the highest positive score?
#     - *bitcoin*

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
from newsapi.newsapi_client import NewsApiClient

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\mksta\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable && # Create a newsapi client
# YOUR CODE HERE!
load_dotenv()
newsapi = NewsApiClient(api_key=os.environ["news_api"])
sid = SentimentIntensityAnalyzer()

# %%
# Fetch the Bitcoin news articles
# YOUR CODE HERE!
bitcoin = newsapi.get_everything(q="bitcoin", language = "en")

# %%
# Fetch the Ethereum news articles
# YOUR CODE HERE!
ethereum = newsapi.get_everything(q="ethereum", language = "en")

# %%
# Create the Bitcoin sentiment scores DataFrame
# YOUR CODE HERE!
bitcoin_sentiments = []
for article in bitcoin["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:3]
        sentiment = sid.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        bitcoin_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
        })
    except AttributeError:
        pass
btc_df = pd.DataFrame(bitcoin_sentiments)

# %%
# Create the Ethereum sentiment scores DataFrame
# YOUR CODE HERE!
ethereum_sentiments = []
for article in ethereum["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:3]
        sentiment = sid.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        ethereum_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
        })
    except AttributeError:
        pass
eth_df = pd.DataFrame(ethereum_sentiments)

# %%
# Describe the Bitcoin Sentiment
# YOUR CODE HERE!
btc_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean   -0.091585   0.059550   0.079700   0.860700
# std     0.401681   0.062411   0.078177   0.104845
# min    -0.859300   0.000000   0.000000   0.557000
# 25%    -0.381800   0.000000   0.039000   0.827000
# 50%    -0.162400   0.049000   0.063000   0.888000
# 75%     0.156025   0.085000   0.103750   0.930250
# max     0.750600   0.202000   0.300000   0.964000

# %%
# Describe the Ethereum Sentiment
# YOUR CODE HERE!
eth_df.describe()
# Out:
#         compound   positive   negative   neutral
# count  20.000000  20.000000  20.000000  20.00000
# mean   -0.055585   0.039550   0.046150   0.91440
# std     0.365057   0.055696   0.044724   0.05249
# min    -0.690800   0.000000   0.000000   0.82200
# 25%    -0.273200   0.000000   0.000000   0.86350
# 50%    -0.127900   0.000000   0.050000   0.93600
# 75%     0.109025   0.066000   0.068250   0.95425
# max     0.690800   0.178000   0.178000   1.00000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: BITCOIN
#
# Q: Which coin had the highest compound score?
#
# A: BITCOIN
#
# Q. Which coin had the highest positive score?
#
# A: BITCOIN

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
# YOUR CODE HERE!
lemmatizer = WordNetLemmatizer()
# Create a list of stopwords
# YOUR CODE HERE!
sw = set(stopwords.words('english'))

# Expand the default stopwords list if necessary
# YOUR CODE HERE!
sw_addon=[]

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Remove the punctuation from text
    re_clean = re.compile("[^a-zA-Z ]").sub('', text)
    # Create a tokenized list of the words
    words = word_tokenize(re_clean)
    
    # Lemmatize words into root words
    result = [lemmatizer.lemmatize(word) for word in words]
       
    # Convert the words to lowercase
    # Remove the stop words
    token = [word.lower() for word in result if word.lower() not in sw.union(sw_addon)]
 
    tokens=token
    
    return tokens

# %%
# Create a new tokens column for Bitcoin
# YOUR CODE HERE!

btc_df['tokens'] = btc_df['text'].apply(word_tokenize)
btc_df.head()
# Out:
#                                                 text date  compound  positive  \
# 0  Now, even though there are a number of women-f...  202    0.0772     0.036
# 1  A Bitcoin mining site powered by otherwise los...  202   -0.0516     0.056
# 2  Warren Buffett has always been a bitcoin skept...  202   -0.3269     0.085
# 3  As a kid, I remember when my father tried to u...  202    0.3818     0.114
# 4  Image source, Getty Images\r\nThe value of Bit...  202    0.3400     0.072
#
#    negative  neutral                                             tokens
# 0     0.000    0.964  [Now, ,, even, though, there, are, a, number, ...
# 1     0.061    0.882  [A, Bitcoin, mining, site, powered, by, otherw...
# 2     0.143    0.772  [Warren, Buffett, has, always, been, a, bitcoi...
# 3     0.052    0.833  [As, a, kid, ,, I, remember, when, my, father,...
# 4     0.000    0.928  [Image, source, ,, Getty, Images, The, value, ...

# %%
# Create a new tokens column for Ethereum
# YOUR CODE HERE!
eth_df['tokens'] = eth_df['text'].apply(word_tokenize)
eth_df.head()
# Out:
#                                                 text date  compound  positive  \
# 0  Meta has revealed more of how NFTs will work o...  202    0.6486     0.135
# 1  GameStop has officially thrown itself headlong...  202   -0.1027     0.000
# 2  A multi-billion dollar cryptocurrency company ...  202   -0.2263     0.046
# 3  When Bored Ape Yacht Club creators Yuga Labs a...  202   -0.2732     0.000
# 4  GameStop is going all-in on crypto. The video ...  202    0.1280     0.046
#
#    negative  neutral                                             tokens
# 0     0.000    0.865  [Meta, has, revealed, more, of, how, NFTs, wil...
# 1     0.040    0.960  [GameStop, has, officially, thrown, itself, he...
# 2     0.075    0.879  [A, multi-billion, dollar, cryptocurrency, com...
# 3     0.055    0.945  [When, Bored, Ape, Yacht, Club, creators, Yuga...
# 4     0.000    0.954  [GameStop, is, going, all-in, on, crypto, ., T...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
# YOUR CODE HERE!
text=''
for content in btc_df['tokens']:
     text = text + str(content)
processed_btc = tokenizer(text)
#word_counts = Counter(processed)
bigram_counts_btc = Counter(ngrams(processed_btc, n=2))
print(dict(bigram_counts_btc))
# Out:
# {('even', 'though'): 1, ('though', 'number'): 1, ('number', 'womenfocused'): 1, ('womenfocused', 'crypto'): 1, ('crypto', 'space'): 1, ('space', 'odeniran'): 1, ('odeniran', 'say'): 1, ('say', 'woman'): 1, ('woman', 'still'): 1, ('still', 'underrepresented'): 1, ('underrepresented', 'ive'): 1, ('ive', 'space'): 1, ('space', 'im'): 1, ('im', 'black'): 1, ('black', 'person'): 1, ('person', 'woman'): 1, ('woman', 'b'): 1, ('b', 'char'): 2, ('char', 'bitcoin'): 1, ('bitcoin', 'mining'): 1, ('mining', 'site'): 1, ('site', 'powered'): 1, ('powered', 'otherwise'): 1, ('otherwise', 'lost'): 1, ('lost', 'gas'): 1, ('gas', 'oil'): 1, ('oil', 'well'): 1, ('well', 'near'): 1, ('near', 'linden'): 1, ('linden', 'texas'): 1, ('texas', 'april'): 1, ('april', 'th'): 1, ('th', 'photo'): 1, ('photo', 'francois'): 1, ('francois', 'picardafp'): 1, ('picardafp', 'via'): 1, ('via', 'getty'): 1, ('getty', 'images'): 2, ('images', 'corporate'): 1, ('corporate', 'climate'): 1, ('climate', 'hype'): 1, ('hype', 'fl'): 1, ('fl', 'char'): 1, ('char', 'warren'): 1, ('warren', 'buffett'): 1, ('buffett', 'ha'): 1, ('ha', 'always'): 1, ('always', 'bitcoin'): 1, ('bitcoin', 'skeptic'): 1, ('skeptic', 'billionaire'): 1, ('billionaire', 'investor'): 1, ('investor', 'harsh'): 1, ('harsh', 'word'): 1, ('word', 'yet'): 1, ('yet', 'cryptocurrency'): 1, ('cryptocurrency', 'weekend'): 1, ('weekend', 'buffett'): 1, ('buffett', 'made'): 1, ('made', 'clear'): 1, ('clear', 'opposition'): 1, ('opposition', 'crypt'): 1, ('crypt', 'char'): 1, ('char', 'kid'): 1, ('kid', 'remember'): 1, ('remember', 'father'): 1, ('father', 'tried'): 1, ('tried', 'use'): 1, ('use', 'broom'): 1, ('broom', 'handle'): 1, ('handle', 'last'): 1, ('last', 'ditch'): 1, ('ditch', 'effort'): 1, ('effort', 'support'): 1, ('support', 'roof'): 1, ('roof', 'wa'): 1, ('wa', 'collapsing'): 1, ('collapsing', 'weight'): 1, ('weight', 'nearly'): 1, ('nearly', 'three'): 1, ('three', 'foot'): 1, ('foot', 'snow'): 1, ('snow', 'guess'): 1, ('guess', 'well'): 1, ('well', 'char'): 1, ('char', 'image'): 1, ('image', 'source'): 1, ('source', 'getty'): 1, ('images', 'value'): 1, ('value', 'bitcoin'): 1, ('bitcoin', 'continued'): 1, ('continued', 'fall'): 1, ('fall', 'weekend'): 1, ('weekend', 'dropped'): 1, ('dropped', 'according'): 1, ('according', 'coinbase'): 1, ('coinbase', 'cryptocurrency'): 1, ('cryptocurrency', 'exchange'): 1, ('exchange', 'world'): 1, ('world', 'largest'): 1, ('largest', 'cryp'): 1, ('cryp', 'char'): 1, ('char', 'youve'): 1, ('youve', 'ever'): 1, ('ever', 'felt'): 1, ('felt', 'like'): 1, ('like', 'introducing'): 1, ('introducing', 'vegasstyle'): 1, ('vegasstyle', 'odds'): 1, ('odds', 'retirement'): 1, ('retirement', 'plan'): 1, ('plan', 'youre'): 1, ('youre', 'finally'): 1, ('finally', 'luck'): 1, ('luck', 'last'): 1, ('last', 'week'): 2, ('week', 'fidelity'): 1, ('fidelity', 'investments'): 1, ('investments', 'announced'): 1, ('announced', 'would'): 1, ('would', 'allow'): 1, ('allow', 'investor'): 1, ('investor', 'put'): 1, ('put', 'part'): 1, ('part', 'char'): 1, ('char', 'cryptocurrency'): 1, ('cryptocurrency', 'mixer'): 1, ('mixer', 'sometimes'): 1, ('sometimes', 'used'): 1, ('used', 'help'): 1, ('help', 'online'): 1, ('online', 'criminal'): 1, ('criminal', 'launder'): 1, ('launder', 'stolen'): 1, ('stolen', 'money'): 1, ('money', 'hiding'): 1, ('hiding', 'true'): 1, ('true', 'origin'): 1, ('origin', 'us'): 1, ('us', 'treasury'): 1, ('treasury', 'ready'): 1, ('ready', 'clamp'): 1, ('clamp', 'hostile'): 1, ('hostile', 'government'): 1, ('government', 'char'): 1, ('char', 'photo'): 1, ('photo', 'illustration'): 1, ('illustration', 'grayson'): 1, ('grayson', 'blackmon'): 1, ('blackmon', 'verge'): 1, ('verge', 'photo'): 1, ('photo', 'oliyarnyk'): 1, ('oliyarnyk', 'ccbysa'): 1, ('ccbysa', 'michael'): 1, ('michael', 'chobanian'): 1, ('chobanian', 'president'): 1, ('president', 'blockchain'): 1, ('blockchain', 'association'): 1, ('association', 'ukraine'): 1, ('ukraine', 'terrible'): 1, ('terrible' ...

# %%
# Generate the Ethereum N-grams where N=2
# YOUR CODE HERE!
text=''
for content in eth_df['tokens']:
     text = text + str(content)
processed_eth = tokenizer(text)
#word_counts = Counter(processed)
bigram_counts_eth = Counter(ngrams(processed_eth, n=2))
print(dict(bigram_counts_eth))
# Out:
# {('meta', 'ha'): 1, ('ha', 'revealed'): 1, ('revealed', 'nfts'): 1, ('nfts', 'work'): 1, ('work', 'instagram'): 1, ('instagram', 'usbased'): 1, ('usbased', 'test'): 1, ('test', 'show'): 1, ('show', 'bought'): 1, ('bought', 'created'): 1, ('created', 'free'): 1, ('free', 'connecting'): 1, ('connecting', 'instagram'): 1, ('instagram', 'account'): 1, ('account', 'compatible'): 1, ('compatible', 'digital'): 1, ('digital', 'walle'): 1, ('walle', 'char'): 1, ('char', 'gamestop'): 2, ('gamestop', 'ha'): 1, ('ha', 'officially'): 1, ('officially', 'thrown'): 1, ('thrown', 'headlong'): 1, ('headlong', 'web'): 1, ('web', 'viper'): 1, ('viper', 'nest'): 1, ('nest', 'new'): 1, ('new', 'app'): 1, ('app', 'release'): 1, ('release', 'though'): 1, ('though', 'hard'): 1, ('hard', 'say'): 1, ('say', 'whether'): 1, ('whether', 'proposed'): 1, ('proposed', 'population'): 1, ('population', 'gamers'): 1, ('gamers', 'game'): 1, ('game', 'developer'): 1, ('developer', 'take'): 1, ('take', 'char'): 1, ('char', 'multibillion'): 1, ('multibillion', 'dollar'): 1, ('dollar', 'cryptocurrency'): 1, ('cryptocurrency', 'company'): 1, ('company', 'ha'): 1, ('ha', 'apologised'): 1, ('apologised', 'user'): 1, ('user', 'sale'): 1, ('sale', 'metaverse'): 1, ('metaverse', 'land'): 1, ('land', 'sparked'): 1, ('sparked', 'frenzy'): 1, ('frenzy', 'temporarily'): 1, ('temporarily', 'brought'): 1, ('brought', 'ethereum'): 1, ('ethereum', 'cryptocurrency'): 1, ('cryptocurrency', 'yuga'): 1, ('yuga', 'labs'): 2, ('labs', 'comp'): 1, ('comp', 'char'): 1, ('char', 'bored'): 1, ('bored', 'ape'): 1, ('ape', 'yacht'): 1, ('yacht', 'club'): 2, ('club', 'creator'): 1, ('creator', 'yuga'): 1, ('labs', 'announced'): 1, ('announced', 'otherside'): 1, ('otherside', 'nft'): 1, ('nft', 'collection'): 1, ('collection', 'would'): 1, ('would', 'launch'): 1, ('launch', 'april'): 1, ('april', 'wa'): 1, ('wa', 'predicted'): 1, ('predicted', 'many'): 1, ('many', 'biggest'): 1, ('biggest', 'nft'): 1, ('nft', 'launch'): 1, ('launch', 'ever'): 1, ('ever', 'otherside'): 1, ('otherside', 'upcoming'): 1, ('upcoming', 'bore'): 1, ('bore', 'char'): 1, ('gamestop', 'going'): 1, ('going', 'allin'): 1, ('allin', 'crypto'): 1, ('crypto', 'video'): 1, ('video', 'game'): 1, ('game', 'retailer'): 1, ('retailer', 'launched'): 1, ('launched', 'selfcustodial'): 1, ('selfcustodial', 'ethereum'): 1, ('ethereum', 'digital'): 1, ('digital', 'wallet'): 1, ('wallet', 'said'): 1, ('said', 'monday'): 1, ('monday', 'wallet'): 1, ('wallet', 'accessible'): 1, ('accessible', 'google'): 1, ('google', 'chrome'): 1, ('chrome', 'extension'): 1, ('extension', 'char'): 1, ('char', 'davos'): 1, ('davos', 'switzerland'): 1, ('switzerland', 'may'): 1, ('may', 'reuters'): 4, ('reuters', 'ethereum'): 1, ('ethereum', 'cofounder'): 1, ('cofounder', 'gavin'): 1, ('gavin', 'wood'): 1, ('wood', 'said'): 1, ('said', 'cryptocurrency'): 1, ('cryptocurrency', 'investor'): 1, ('investor', 'need'): 1, ('need', 'aware'): 1, ('aware', 'backing'): 1, ('backing', 'holding'): 1, ('holding', 'market'): 1, ('market', 'rout'): 1, ('rout', 'wiped'): 1, ('wiped', 'char'): 1, ('char', 'april'): 2, ('april', 'reuters'): 2, ('reuters', 'ether'): 1, ('ether', 'ha'): 1, ('ha', 'promised'): 2, ('promised', 'better'): 1, ('better', 'ha'): 1, ('promised', 'go'): 1, ('go', 'next'): 1, ('next', 'level'): 1, ('level', 'edging'): 1, ('edging', 'crypto'): 1, ('crypto', 'rival'): 1, ('rival', 'even'): 1, ('even', 'outshining'): 1, ('outshining', 'godfather'): 1, ('godfather', 'bitcoin'): 1, ('bitcoin', 'clock'): 1, ('clock', 'ticking'): 1, ('ticking', 'char'): 1, ('char', 'ethereum'): 1, ('ethereum', 'preparing'): 1, ('preparing', 'upgrade'): 1, ('upgrade', 'thats'): 1, ('thats', 'described'): 1, ('described', 'single'): 1, ('single', 'important'): 1, ('important', 'event'): 1, ('event', 'crypto'): 1, ('crypto', 'history'): 1, ('history', 'transition'): 1, ('transition', 'would'): 1, ('would', 'overhaul'): 1, ('overhaul', 'infrastructure'): 1, ('infrastructure', 'wor ...

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
# YOUR CODE HERE!
token_count(bigram_counts_btc,5)
# Out:
# [(('may', 'reuters'), 5),
#  (('reuters', 'bitcoin'), 5),
#  (('previous', 'close'), 4),
#  (('close', 'bitcoin'), 4),
#  (('bitcoin', 'world'), 4)]

# %%
# Use token_count to get the top 10 words for Ethereum
# YOUR CODE HERE!
token_count(bigram_counts_eth,5)
# Out:
# [(('may', 'reuters'), 4),
#  (('reuters', 'bitcoin'), 4),
#  (('previous', 'close'), 4),
#  (('close', 'bitcoin'), 4),
#  (('bitcoin', 'world'), 4)]

# %%
# Use token_count to get the top 10 words for Bitcoin
# YOUR CODE HERE!
token_count(processed_btc,10)
# Out:
# [('char', 19),
#  ('bitcoin', 16),
#  ('cryptocurrency', 11),
#  ('world', 6),
#  ('week', 6),
#  ('reuters', 6),
#  ('may', 5),
#  ('biggest', 5),
#  ('ha', 4),
#  ('investor', 4)]

# %%
# Use token_count to get the top 10 words for Ethereum
# YOUR CODE HERE!
token_count(processed_eth,10)
# Out:
# [('char', 20),
#  ('bitcoin', 11),
#  ('cryptocurrency', 10),
#  ('ha', 8),
#  ('ethereum', 7),
#  ('may', 6),
#  ('reuters', 6),
#  ('world', 6),
#  ('biggest', 5),
#  ('last', 5)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
wc_clean_btc = re.compile("[^a-zA-Z ]").sub('',str(processed_btc))

# %%
# Generate the Bitcoin word cloud
# YOUR CODE HERE!
wc = WordCloud().generate(wc_clean_btc)
plt.title('Bitcoin Wordcloud')
plt.imshow(wc);

# %%
# Generate the Ethereum word cloud
# YOUR CODE HERE!
wc_clean_eth = re.compile("[^a-zA-Z ]").sub('',str(processed_eth))
wc = WordCloud().generate(wc_clean_eth)
plt.title('Ethereum WordCloud')
plt.imshow(wc);

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
# Run the NER processor on all of the text
# YOUR CODE HERE!
doc = nlp(str(btc_df['text']))
# Add a title to the document
# YOUR CODE HERE!
doc.user_data['title'] = 'Bitcoin Named Entity Recognition'

# %%
# Render the visualization
# YOUR CODE HERE!
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin Named Entity Recognition</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">0     Now, even though there are a number of women-f...</br>1     A Bitcoin mining site powered by otherwise los...</br>2
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Warren Buffett
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has always been a bitcoin skept...</br>3     As a kid, I remember when my father tried to u...</br>4     Image source,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Getty Images\r\nThe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  value of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ...</br>5     If youve ever felt like introducing some Vegas...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      Cryptocurrency mixers are sometimes used to he...</br>7     Photo Illustration by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Grayson Blackmon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  / The V...</br>8     Posted \r\nFrom
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's dramatic drop to a n...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     9
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 11
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Bitcoin fell
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     7.23%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  to $28,7...</br>10
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Bitcoin rose
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5.7%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  to $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     39,862
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# ...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     11
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April 26
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Bitcoin dropped
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5.1%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  to $...</br>12    BTC fell to its lowest level since
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last July
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , ...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     13
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 9
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Bitcoin dropped
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     7.81%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  to $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     31
#     <span style="font-size: 0.8em; font-weight: bold; line-he

# %%
# List all Entities
# YOUR CODE HERE!
print([ent.text for ent in doc.ents ])
# Out:
# ['Warren Buffett', 'Getty Images\\r\\nThe', 'Bit', '6', 'Grayson Blackmon', 'Bitcoin', '9', 'May 11', 'Reuters', '7.23%', 'May 4', 'Reuters', '5.7%', '39,862', '11', 'April 26', 'Reuters', '5.1%', 'last July', '13', 'May 9', 'Reuters', '7.81%', '31', '14', 'Mexican', 'North London', 'May 24', 'Reuters', 'May 10', 'Reuters', '17', 'The Central African Republic', 'bitco', 'two', 'Sam Bankman-Fried']

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
# Run the NER processor on all of the text
# YOUR CODE HERE!
doc = nlp(str(eth_df['text']))
# Add a title to the document
# YOUR CODE HERE!
doc.user_data['title'] = 'Ethereum Named Entity Recognition'

# %%
# Render the visualization
# YOUR CODE HERE!
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum Named Entity Recognition</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     0     Meta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has revealed more of how NFTs will work o...</br>1     GameStop has officially thrown itself headlong...</br>2     A multi-billion dollar cryptocurrency company ...</br>3     When Bored Ape
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Yacht Club
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  creators
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Yuga Labs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  a...</br>4
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GameStop
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  is going all-in on crypto. The video ...</br>5     DAVOS,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Switzerland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 25
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Ethereu...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April 26
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Ether has promised to do ...</br>7     Ethereum is preparing for an upgrade that
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     s bee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ...</br>8     There's a new metaverse project from the creat...</br>9     Editorial IndependenceWe want to help you make...</br>10    40 days ago Bitcoin sold for $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     47,454
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# . It's
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pri
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ...</br>11    When
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nvidia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  launched its
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ampere Lite Hash Rate
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# ...</br>12
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Bitcoin rose
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5.7%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  to $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     39,862
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# ...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     13
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April 26
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Bitcoin dropped
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5.1%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  to $...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     14
#     <span style="font-size: 0.8em; font-weight: bold; line-he

# %%
# List all Entities
# YOUR CODE HERE!
print([ent.text for ent in doc.ents ])
# Out:
# ['0     Meta', 'Yacht Club', 'Yuga Labs', 'GameStop', 'Switzerland', 'May 25', 'Reuters', '6', 'April 26', 'Reuters', 's bee', '47,454', 'pri', 'Nvidia', 'Ampere Lite Hash Rate', 'May 4', 'Reuters', '5.7%', '39,862', '13', 'April 26', 'Reuters', '5.1%', '14', 'May 11', 'Reuters', '7.23%', 'May 9', 'Reuters', '7.81%', '31', '16', '8', 'NFT', 'last July', 'the past few year']

# %% [markdown]
# ---
