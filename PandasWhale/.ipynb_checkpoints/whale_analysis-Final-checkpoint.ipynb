# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path
# %matplotlib inline

print (Path.cwd())
filepathWhale=Path('~/GitHub/python-homework/PandasWhale/Resources/whale_returns.csv')
filepathAlgo=Path('~/GitHub/python-homework/PandasWhale/Resources/algo_returns.csv')
filepathSP=Path('~/GitHub/python-homework/PandasWhale/Resources/sp500_history.csv')
filepathTQQQ=Path('~/GitHub/python-homework/PandasWhale/Resources/TQQQ.csv')
filepathTMF=Path('~/GitHub/python-homework/PandasWhale/Resources/TMF.csv')
filepathSCHD=Path('~/GitHub/python-homework/PandasWhale/Resources/SCHD.csv')

print (filepathWhale)
# Out:
# C:\Users\mksta\GitHub\python-homework-public\PandasWhale
# ~\GitHub\python-homework\PandasWhale\Resources\whale_returns.csv

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
#nflx=pd.read_csv(filePathNFLX,index_col="date", infer_datetime_format=True, parse_dates=True).dropna()#
whale_returns = pd.read_csv(filepathWhale,index_col='Date',infer_datetime_format=True,parse_dates=True)

# %%
# Count nulls
print (whale_returns.isna().count())
# Out:
# SOROS FUND MANAGEMENT LLC      1060
# PAULSON & CO.INC.              1060
# TIGER GLOBAL MANAGEMENT LLC    1060
# BERKSHIRE HATHAWAY INC         1060
# dtype: int64

# %%
# Drop nulls
whale_returns.dropna()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# ...

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_returns = pd.read_csv(filepathAlgo,index_col='Date',infer_datetime_format=True,parse_dates=True)

# %%
# Count nulls
print (algo_returns.isna().count())
# Out:
# Algo 1    1241
# Algo 2    1241
# dtype: int64

# %%
# Drop nulls
algo_returns.dropna()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1235 rows x 2 columns]

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
SP_history = pd.read_csv(filepathSP,index_col='Date',infer_datetime_format=True,parse_dates=True)

# %%
# Check Data Types
SP_history.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
SP_history['Close']=SP_history['Close'].str.replace('$','',regex=False)
SP_history['Close']=SP_history['Close'].astype(float)
SP_history.dtypes
# Out:
# Close    float64
# dtype: object

# %%
# Calculate Daily Returns
SP_returns=SP_history.pct_change()

# %%
# Drop nulls
SP_returns.dropna()
# Out:
#                Close
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509
# ...              ...
# 2012-10-05  0.003469
# 2012-10-04  0.000322
# 2012-10-03 -0.007123
# 2012-10-02 -0.003611
# 2012-10-01 -0.000872
#
# [1648 rows x 1 columns]

# %%
# Rename `Close` Column to be specific to this portfolio.
SP_returns=SP_returns.rename(columns={'Close':'SP500'}).dropna()

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
combined_returns=pd.concat([whale_returns,algo_returns,SP_returns], axis="columns", join="inner").dropna()
combined_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2     SP500
# Date
# 2015-03-03 -0.000949  0.004408
# 2015-03-04  0.002416 -0.001195
# 2015-03-05  0.004323  0.014378
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
combined_returns.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns=(1+combined_returns).cumprod()
# Plot cumulative returns
cumulative_returns.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
combined_returns.plot.box(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
combined_returns.std()
# Out:
# SOROS FUND MANAGEMENT LLC      0.007896
# PAULSON & CO.INC.              0.007026
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007623
# Algo 2                         0.008341
# SP500                          0.008587
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
SP_only=combined_returns['SP500'].std()
# Determine which portfolios are riskier than the S&P 500
combined_returns.std() > SP_only
# Out:
# SOROS FUND MANAGEMENT LLC      False
# PAULSON & CO.INC.              False
# TIGER GLOBAL MANAGEMENT LLC     True
# BERKSHIRE HATHAWAY INC          True
# Algo 1                         False
# Algo 2                         False
# SP500                          False
# dtype: bool

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
combined_returns.std() * np.sqrt(252)
# Out:
# SOROS FUND MANAGEMENT LLC      0.125348
# PAULSON & CO.INC.              0.111527
# TIGER GLOBAL MANAGEMENT LLC    0.172989
# BERKSHIRE HATHAWAY INC         0.205079
# Algo 1                         0.121006
# Algo 2                         0.132413
# SP500                          0.136313
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
combined_returns.rolling(21).std().dropna().plot(figsize=(20,10))
# Plot the rolling standard deviation
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
# Display de correlation matrix
correllation=combined_returns.corr()
sns.heatmap(correllation,vmin=-.5,vmax=.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
#rolling_covariance = daily_returns['AMZN'].rolling(window=30).cov(daily_returns['S&P 500'])
rolling_covariance=combined_returns['Algo 1'].rolling(window=30).cov(combined_returns['SP500'])
rolling_covariance
# Calculate variance of S&P 500
rolling_variance=combined_returns['SP500'].rolling(window=30).var()
rolling_variance
# Computing beta
a_beta=rolling_covariance/rolling_variance
a_beta
# Plot beta trend
a_beta.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window
combined_returns.ewm(halflife=21).mean()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.000511           -0.000802
# 2015-03-05                   0.001718            0.000878
# 2015-03-06                  -0.000808           -0.000291
# 2015-03-09                  -0.000511            0.000673
# ...                               ...                 ...
# 2019-04-15                   0.001439            0.000450
# 2019-04-16                   0.001480            0.000448
# 2019-04-17                   0.001338            0.000223
# 2019-04-18                   0.001341            0.000256
# 2019-04-22                   0.001214            0.000009
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.001532               -0.001089 -0.005320
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratio= (combined_returns.mean() -0) / (combined_returns.std() * np.sqrt(252))
sharpe_ratio.head()
# Out:
# SOROS FUND MANAGEMENT LLC      0.001361
# PAULSON & CO.INC.             -0.001950
# TIGER GLOBAL MANAGEMENT LLC   -0.000517
# BERKSHIRE HATHAWAY INC         0.002408
# Algo 1                         0.005435
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratio.plot(kind='bar', figsize=(20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Algo 1 portfolio outperforms the Whales and S&P 500. Algo 2 performs better than S&P 500 and most of the Whale portfolios however it did not outperform Whale portfolio of Berkshire Hathaway.

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
df_TQQQ = pd.read_csv(filepathTQQQ,index_col='Date',infer_datetime_format=True,parse_dates=True)
df_TQQQ.columns = ['TQQQ']
df_TQQQ.head()
# Out:
#                 TQQQ
# Date
# 2012-01-03  0.746672
# 2012-01-04  0.755607
# 2012-01-05  0.774206
# 2012-01-06  0.782207
# 2012-01-09  0.775661

# %%
# Reading data from 2nd stock
df_TMF = pd.read_csv(filepathTMF,index_col='Date',infer_datetime_format=True,parse_dates=True)
df_TMF.columns = ['TMF']
df_TMF.head()
# Out:
#                   TMF
# Date
# 2012-01-03  15.780339
# 2012-01-04  15.247171
# 2012-01-05  15.145616
# 2012-01-06  15.482597
# 2012-01-09  15.406428

# %%
# Reading data from 3rd stock
df_SCHD = pd.read_csv(filepathSCHD,index_col='Date',infer_datetime_format=True,parse_dates=True)
df_SCHD.columns = ['SCHD']
df_SCHD.head()
# Out:
#                  SCHD
# Date
# 2012-01-03  19.454433
# 2012-01-04  19.454433
# 2012-01-05  19.439705
# 2012-01-06  19.351339
# 2012-01-09  19.395519

# %%
# Combine all stocks in a single DataFrame
df_custom_portfolio=pd.concat([df_TQQQ,df_TMF,df_SCHD], axis="columns", ignore_index=True).dropna()
df_custom_portfolio.columns = ["TQQQ","TMF","SCHD"]
df_custom_portfolio.head()
# Out:
#                 TQQQ        TMF       SCHD
# Date
# 2012-01-03  0.746672  15.780339  19.454433
# 2012-01-04  0.755607  15.247171  19.454433
# 2012-01-05  0.774206  15.145616  19.439705
# 2012-01-06  0.782207  15.482597  19.351339
# 2012-01-09  0.775661  15.406428  19.395519

# %%
# Calculate daily returns & # Drop NAs
custom_portfolio_returns = df_custom_portfolio.pct_change().dropna()

# Display sample data
custom_portfolio_returns.head()
# Out:
#                 TQQQ       TMF      SCHD
# Date
# 2012-01-04  0.011966 -0.033787  0.000000
# 2012-01-05  0.024615 -0.006661 -0.000757
# 2012-01-06  0.010334  0.022249 -0.004546
# 2012-01-09 -0.008369 -0.004920  0.002283
# 2012-01-10  0.020496 -0.004045  0.006834

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
returns = custom_portfolio_returns.dot(weights)
returns.columns = ["My_Portfolio"]
# Display sample data
returns.head()
# Out:
# Date
# 2012-01-04   -0.007273
# 2012-01-05    0.005732
# 2012-01-06    0.009346
# 2012-01-09   -0.003668
# 2012-01-10    0.007762
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
all_returns=pd.concat([combined_returns,returns], axis="columns", ignore_index=True).dropna()
all_returns.columns = ["SOROS FUND MANAGEMENT LLC","PAULSON & CO.INC.","TIGER GLOBAL MANAGEMENT LLC","BERKSHIRE HATHAWAY INC","Algo 1","Algo 2","SP500","Custom"]
all_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.  \
# Date
# 2015-03-03                  -0.001266          -0.004981
# 2015-03-04                   0.002230           0.003241
# 2015-03-05                   0.004016           0.004076
# 2015-03-06                  -0.007905          -0.003574
# 2015-03-09                   0.000582           0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2     SP500    Custom
# Date
# 2015-03-03 -0.000949  0.004408 -0.010310
# 2015-03-04  0.002416 -0.001195 -0.003653
# ...

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
all_returns.std()* np.sqrt(252)
# Out:
# SOROS FUND MANAGEMENT LLC      0.125348
# PAULSON & CO.INC.              0.111527
# TIGER GLOBAL MANAGEMENT LLC    0.172989
# BERKSHIRE HATHAWAY INC         0.205079
# Algo 1                         0.121006
# Algo 2                         0.132413
# SP500                          0.136313
# Custom                         0.209595
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
# Plot rolling standard deviation
all_returns.rolling(21).std().dropna().plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
al_correllation=all_returns.corr()
al_correllation.head()
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.  \
# SOROS FUND MANAGEMENT LLC                     1.000000           0.699823
# PAULSON & CO.INC.                             0.699823           1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561040           0.434308
# BERKSHIRE HATHAWAY INC                        0.754157           0.545451
# Algo 1                                        0.320901           0.268631
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561040
# PAULSON & CO.INC.                               0.434308
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424125
# Algo 1                                          0.164114
#
#                              BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  \
# SOROS FUND MANAGEMENT LLC                  0.754157  0.320901  0.826730
# ...

# %%
sns.heatmap(al_correllation,vmin=-.7,vmax=.7)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
rolling_covariance=all_returns['Custom'].rolling(window=60).cov(all_returns['SP500'])
rolling_covariance
# Calculate variance of S&P 500
rolling_variance=all_returns['SP500'].rolling(window=60).var()
rolling_variance
# Computing beta
a_beta=rolling_covariance/rolling_variance
a_beta
# Plot beta trend
a_beta.plot(figsize=(20,10));

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
sharpe_ratio= (all_returns.mean() -0) / (all_returns.std() * np.sqrt(252))
sharpe_ratio
# Out:
# SOROS FUND MANAGEMENT LLC      0.001361
# PAULSON & CO.INC.             -0.001950
# TIGER GLOBAL MANAGEMENT LLC   -0.000517
# BERKSHIRE HATHAWAY INC         0.002408
# Algo 1                         0.005435
# Algo 2                         0.001922
# SP500                         -0.002058
# Custom                         0.003630
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratio.plot(kind='bar', figsize=(20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### How does your portfolio do?
# * According to the sharpe ratio it performed better than most on a risk adjuested basis.
# * however it was still quite volatile when looking at the standard deviation.
# Note the stock chosen were ETF's (TQQQ,TMF, and SCHD)
